# %%
import pandas as pd
from os import listdir 
import os 
import glob
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

pd.set_option('display.max_columns', 180)
pd.set_option('display.max_rows', 60000)

# %% [markdown]
# ## Reading in dataset

# %%
all_files = list()

for x in os.listdir():
    if x.endswith('.csv'):
        df = pd.read_csv(x)
        df['file_name'] = x
        df['dataowner'] = "Department of Water and Sanitation South Africa"
        df['contact_person'] = "Ramusiya, Fhedzisani"
        df['email'] = "RamusiyaF@dws.gov.za"
        all_files.append(df)
        dataset = pd.concat(all_files, axis = 0, ignore_index = True, sort = False)

dataset.head(2)
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 0             -25.56581               26.03837                   NaN
# 1             -25.56532               26.02356                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
#    Abstraction_ConversionFactorConstantValue  Abstraction_Quantity  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
#
#    Abstraction_PowerMeterReading Abstraction_WaterMeterCollectiveMeasurement  \
# ...

# %% [markdown]
# ## Assessing

# %%
dataset.info()
#dataset.to_csv('dataset.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26091 entries, 0 to 26090
# Columns: 132 entries, GeositeInfo_DataOwner to YieldTest_Quantity
# dtypes: float64(55), object(77)
# memory usage: 26.3+ MB

# %%
dataset.to_csv('dataset.csv', index = False)

# %%
column_names = list(dataset)
column_names
# Out:
# ['GeositeInfo_DataOwner',
#  'GeositeInfo_Identifier',
#  'GeositeInfo_GeositeType',
#  'GeositeInfo_Latitude',
#  'GeositeInfo_Longitude',
#  'Abstraction_MeterType',
#  'Abstraction_MeasurementDateTime',
#  'Abstraction_HourMeterReading',
#  'Abstraction_ConversionFactorConstantValue',
#  'Abstraction_Quantity',
#  'Abstraction_PowerMeterReading',
#  'Abstraction_WaterMeterCollectiveMeasurement',
#  'Abstraction_WaterMeterReading',
#  'Abstraction_WaterMeterMeasurementReason',
#  'Abstraction_MeasurementMethod',
#  'Abstraction_MeasurementStatus',
#  'file_name',
#  'dataowner',
#  'contact_person',
#  'email',
#  'GeositeInfo_ReferenceDatum',
#  'GeositeInfo_CoordinateMethod',
#  'GeositeInfo_Elevation',
#  'GeositeInfo_FarmName',
#  'GeositeInfo_FarmNumber',
#  'GeositeInfo_Town',
#  'GeositeInfo_Portion',
#  'GeositeInfo_Village',
#  'GeositeInfo_GeositeStatus',
#  'GeositeInfo_DateWhenStatusWasObserved',
#  'GeositeInfo_MapNumber',
#  'GeositeInfo_Province',
# ...

# %%
dataset ['GeositeInfo_Identifier'].nunique()
# Out:
# 1587

# %%
dataset ['file_name'].value_counts(sort = 'ascending')
# Out:
# Lithology_wbw_2019912_95245_DataExport_1.csv           4046
# WaterLevels_wbw_2019912_93751_DataExport_1.csv         3484
# OtherNumbers_wbw_2019912_94720_DataExport_1.csv        3052
# Basic_wbw_2019912_93716_DataExport_1.csv               2240
# WaterStrike_wbw_2019912_9517_DataExport_1.csv          1771
# Discharge_wbw_2019912_9413_DataExport_1.csv            1757
# Yieldtest_wbw_2019912_95158_DataExport_1.csv           1702
# FieldMeasurements_wbw_2019912_9470_DataExport_1.csv    1643
# DepthDiam_wbw_2019912_94753_DataExport_1.csv           1615
# Casings_wbw_2019912_94828_DataExport_1.csv             1605
# Abstraction_wbw_2019912_93856_DataExport_1.csv         1588
# Equipment_wbw_2019912_94934_DataExport_1.csv           1588
# Name: file_name, dtype: int64

# %%
print(dataset ['YieldTest_DischargeRate'].unique()[:3])
print(dataset ['DischargeRate_DischargeRate'].unique()[:3])
print(dataset ['DepthDiameter_Diameter'].unique()[:3])
# Out:
# [nan '0.300 l/s' '0.590 l/s']
# [nan '3.750 l/s' '0.650 l/s']
# [nan '165 mm (6.5)"' '152 mm (6.0)"']

# %%
Abs = pd.read_csv ('Abstraction_wbw_2019912_93856_DataExport_1.csv')
Bas = pd.read_csv ('Basic_wbw_2019912_93716_DataExport_1.csv')
Casings = pd.read_csv ('Casings_wbw_2019912_94828_DataExport_1.csv') 
DepthDiam = pd.read_csv ('DepthDiam_wbw_2019912_94753_DataExport_1.csv')
Discharge = pd.read_csv ('Discharge_wbw_2019912_9413_DataExport_1.csv')
Equipment = pd.read_csv ('Equipment_wbw_2019912_94934_DataExport_1.csv')  
FieldMeasurements = pd.read_csv ('FieldMeasurements_wbw_2019912_9470_DataExport_1.csv')
Lithology = pd.read_csv ('Lithology_wbw_2019912_95245_DataExport_1.csv')
OtherNumbers = pd.read_csv ('OtherNumbers_wbw_2019912_94720_DataExport_1.csv')
WaterLevels = pd.read_csv ('WaterLevels_wbw_2019912_93751_DataExport_1.csv')
WaterStrike = pd.read_csv ('WaterStrike_wbw_2019912_9517_DataExport_1.csv')
Yieldtest = pd.read_csv ('Yieldtest_wbw_2019912_95158_DataExport_1.csv')

# %%
print('Abs: \n {}'.format(Abs ['GeositeInfo_Identifier'].nunique()))
print('Bas: \n {}'.format(Bas ['GeositeInfo_Identifier'].nunique()))
print('Casings: \n {}'.format(Casings ['GeositeInfo_Identifier'].nunique()))
print('DepthDiam: \n {}'.format(DepthDiam ['GeositeInfo_Identifier'].nunique()))
print('Discharge: \n {}'.format(Discharge ['GeositeInfo_Identifier'].nunique()))
print('Equipment: \n {}'.format(Equipment ['GeositeInfo_Identifier'].nunique()))
print('FieldMeasurements: \n {}'.format(FieldMeasurements ['GeositeInfo_Identifier'].nunique()))
print('Lithology: \n {}'.format(Lithology ['GeositeInfo_Identifier'].nunique()))
print('OtherNumbers: \n {}'.format(OtherNumbers ['GeositeInfo_Identifier'].nunique()))
print('WaterLevels: \n {}'.format(WaterLevels ['GeositeInfo_Identifier'].nunique()))
print('WaterStrike: \n {}'.format(WaterStrike ['GeositeInfo_Identifier'].nunique()))
print('Yieldtest: \n {}'.format(Yieldtest ['GeositeInfo_Identifier'].nunique()))
# Out:
# Abs:
#  1587
# Bas:
#  1587
# Casings:
#  1587
# DepthDiam:
#  1587
# Discharge:
#  1587
# Equipment:
#  1587
# FieldMeasurements:
#  1587
# Lithology:
#  1587
# OtherNumbers:
#  1587
# WaterLevels:
#  1587
# WaterStrike:
#  1587
# Yieldtest:
#  1587

# %%
print('Abs: \n {}'.format(Abs.shape))
print('Bas: \n {}'.format(Bas.shape))
print('Casings: \n {}'.format(Casings.shape))
print('DepthDiam: \n {}'.format(DepthDiam.shape))
print('Discharge: \n {}'.format(Discharge.shape))
print('Equipment: \n {}'.format(Equipment.shape))
print('FieldMeasurements: \n {}'.format(FieldMeasurements.shape))
print('Lithology: \n {}'.format(Lithology.shape))
print('OtherNumbers: \n {}'.format(OtherNumbers.shape))
print('WaterLevels: \n {}'.format(WaterLevels.shape))
print('WaterStrike: \n {}'.format(WaterStrike.shape))
print('Yieldtest: \n {}'.format(Yieldtest.shape))
# Out:
# Abs:
#  (1588, 16)
# Bas:
#  (2240, 30)
# Casings:
#  (1605, 11)
# DepthDiam:
#  (1615, 9)
# Discharge:
#  (1757, 9)
# Equipment:
#  (1588, 20)
# FieldMeasurements:
#  (1643, 11)
# Lithology:
#  (4046, 32)
# OtherNumbers:
#  (3052, 7)
# WaterLevels:
#  (3484, 12)
# WaterStrike:
#  (1771, 13)
# Yieldtest:
#  (1702, 13)

# %%
unique_bh_ids = list(Abs ['GeositeInfo_Identifier'].unique())

# %%
pd.set_option('display.max_columns', 32)
pd.set_option('display.max_rows', 4046)

# %% [markdown]
# ## Abstraction_wbw_2019912_93856_DataExport_1.csv

# %%
Abs.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 0             -25.56581               26.03837                   NaN
# 1             -25.56532               26.02356                   NaN
# 2             -25.56523               26.03843                   NaN
# 3             -25.56503               25.99131                   NaN
# 4             -25.56449               26.02662                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# ...

# %%
Abs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1588 entries, 0 to 1587
# Data columns (total 16 columns):
# GeositeInfo_DataOwner                          1588 non-null object
# GeositeInfo_Identifier                         1588 non-null object
# GeositeInfo_GeositeType                        1588 non-null object
# GeositeInfo_Latitude                           1588 non-null float64
# GeositeInfo_Longitude                          1588 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
print (Abs ['Abstraction_MeterType'].unique())
print (Abs ['Abstraction_MeasurementDateTime'].unique())
print (Abs ['Abstraction_Quantity'].unique())
print (Abs ['Abstraction_WaterMeterCollectiveMeasurement'].unique())
print (Abs ['Abstraction_MeasurementMethod'].unique())
print (Abs ['Abstraction_MeasurementStatus'].unique())
# Out:
# [nan 'No Meter']
# [nan '2001-08-05 12:00:00']
# [  nan 3888.]
# [nan False]
# [nan 'Estimated']
# [nan 'Calculated']

# %%
abs_use	For production boreholes (data field bh_type): What is the main use of the borehole. Choose 1: Domestic, Agriculture, Industrial, Water Supply, Other, Unknown, Non-applicable (= for non-equipped boreholes)
abs_avg	Average abstraction rate: Estimated or measured abstraction rate [m3/day]
abs_rely	Method to establish abstraction rate. Choose 1: Estimated, Metered, Unknown
abs_series	Are time series of groundwater levels available: Choose 1: Yes, No, Unknown.
abstr_db	Name of database / organisation where time series can be obtained.
abstr_id	Alternative BH-number or BH-id if time series records are kept under different numbers.
abstr_strt	Date. Format: [yyyy-mm-dd]. If exact date not known choose first day of month or of year. If no data: -9999
abstr_end	Date. Format: [yyyy-mm-dd].  Choose 1: End date, or if continuing: 2100-01-01, or if unknown: -9999

# %% [markdown]
# ## Basic_wbw_2019912_93716_DataExport_1.csv

# %%
Bas.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude   GeositeInfo_ReferenceDatum  \
# 0             -25.56581               26.03837  Hartbeeshoek Datum (WGS 84)
# 1             -25.56532               26.02356  Hartbeeshoek Datum (WGS 84)
# 2             -25.56523               26.03843  Hartbeeshoek Datum (WGS 84)
# 3             -25.56503               25.99131  Hartbeeshoek Datum (WGS 84)
# 4             -25.56449               26.02662  Hartbeeshoek Datum (WGS 84)
#
#             GeositeInfo_CoordinateMethod  GeositeInfo_Elevation  \
# ...

# %%
Bas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
# GeositeInfo_DataOwner                    2240 non-null object
# GeositeInfo_Identifier                   2240 non-null object
# GeositeInfo_GeositeType                  2240 non-null object
# GeositeInfo_Latitude                     2240 non-null float64
# GeositeInfo_Longitude                    2240 non-null float64
# GeositeInfo_ReferenceDatum               2240 non-null object
# GeositeInfo_CoordinateMethod             2240 non-null object
# GeositeInfo_Elevation                    2240 non-null float64
# GeositeInfo_FarmName                     1939 non-null object
# GeositeInfo_FarmNumber                   1939 non-null object
# GeositeInfo_Town                         82 non-null object
# GeositeInfo_Portion                      102 non-null object
# GeositeInfo_Village                      382 non-null object
# ...

# %% [markdown]
# ## Casings_wbw_2019912_94828_DataExport_1.csv

# %%
Casings.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  Casing_CasingColumnNumber  \
# 0             -25.56581               26.03837                        NaN
# 1             -25.56532               26.02356                        1.0
# 2             -25.56523               26.03843                        1.0
# 3             -25.56503               25.99131                        NaN
# 4             -25.56449               26.02662                        1.0
#
#    Casing_CasingCollarHeight  Casing_DepthToTop  Casing_DepthToBottom  \
# ...

# %%
Casings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 11 columns):
# GeositeInfo_DataOwner        1605 non-null object
# GeositeInfo_Identifier       1605 non-null object
# GeositeInfo_GeositeType      1605 non-null object
# GeositeInfo_Latitude         1605 non-null float64
# GeositeInfo_Longitude        1605 non-null float64
# Casing_CasingColumnNumber    311 non-null float64
# Casing_CasingCollarHeight    311 non-null float64
# Casing_DepthToTop            308 non-null float64
# Casing_DepthToBottom         308 non-null float64
# Casing_CasingMaterial        28 non-null object
# Casing_Diameter              0 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 138.1+ KB

# %% [markdown]
# ## DepthDiam_wbw_2019912_94753_DataExport_1.csv

# %%
DepthDiam.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude DepthDiameter_MeasurementDate  \
# 0             -25.56581               26.03837                    1900-01-01
# 1             -25.56532               26.02356                    1991-10-29
# 2             -25.56523               26.03843                    1990-07-04
# 3             -25.56503               25.99131                    1900-01-01
# 4             -25.56449               26.02662                    1991-11-25
#
#    DepthDiameter_DepthToBottom  DepthDiameter_DepthQualifier  \
# ...

# %%
DepthDiam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 9 columns):
# GeositeInfo_DataOwner            1615 non-null object
# GeositeInfo_Identifier           1615 non-null object
# GeositeInfo_GeositeType          1615 non-null object
# GeositeInfo_Latitude             1615 non-null float64
# GeositeInfo_Longitude            1615 non-null float64
# DepthDiameter_MeasurementDate    1164 non-null object
# DepthDiameter_DepthToBottom      1219 non-null float64
# DepthDiameter_DepthQualifier     1216 non-null object
# DepthDiameter_Diameter           1218 non-null object
# dtypes: float64(3), object(6)
# memory usage: 113.7+ KB

# %% [markdown]
# ## Discharge_wbw_2019912_9413_DataExport_1.csv

# %%
Discharge.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56532               26.02356
# 2             -25.56523               26.03843
# 3             -25.56503               25.99131
# 4             -25.56449               26.02662
#
#   DischargeRate_MeasurementDateAndTime DischargeRate_DischargeRate  \
# 0                  1992-04-01 12:00:00                   3.750 l/s
# 1                                  NaN                         NaN
# ...

# %%
Discharge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 9 columns):
# GeositeInfo_DataOwner                   1757 non-null object
# GeositeInfo_Identifier                  1757 non-null object
# GeositeInfo_GeositeType                 1757 non-null object
# GeositeInfo_Latitude                    1757 non-null float64
# GeositeInfo_Longitude                   1757 non-null float64
# DischargeRate_MeasurementDateAndTime    490 non-null object
# DischargeRate_DischargeRate             490 non-null object
# DischargeRate_DischargeType             490 non-null object
# DischargeRate_DischargeMethod           10 non-null object
# dtypes: float64(2), object(7)
# memory usage: 123.7+ KB

# %% [markdown]
# ## Equipment_wbw_2019912_94934_DataExport_1.csv

# %%
Equipment.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56532               26.02356
# 2             -25.56523               26.03843
# 3             -25.56503               25.99131
# 4             -25.56449               26.02662
#
#   EquipmentInstalled_MonitoringType EquipmentInstalled_InstallationDate  \
# 0                    Non Monitoring                          1990-07-04
# 1                               NaN                                 NaN
# ...

# %%
Equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1588 entries, 0 to 1587
# Data columns (total 20 columns):
# GeositeInfo_DataOwner                                   1588 non-null object
# GeositeInfo_Identifier                                  1588 non-null object
# GeositeInfo_GeositeType                                 1588 non-null object
# GeositeInfo_Latitude                                    1588 non-null float64
# GeositeInfo_Longitude                                   1588 non-null float64
# EquipmentInstalled_MonitoringType                       169 non-null object
# EquipmentInstalled_InstallationDate                     169 non-null object
# EquipmentInstalled_DecommissionedDate                   0 non-null float64
# EquipmentInstalled_PumpType                             117 non-null object
# EquipmentInstalled_DepthtoPumpIntake                    0 non-null float64
# EquipmentInstalled_PumpPowerSource                      0 non-null float64
# ...

# %% [markdown]
# ## FieldMeasurements_wbw_2019912_9470_DataExport_1.csv

# %%
 FieldMeasurements.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria                 039905                Borehole
# 3  Dept Water - Pretoria                 039905                Borehole
# 4  Dept Water - Pretoria            2526CA00495                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56532               26.02356
# 2             -25.56532               26.02356
# 3             -25.56532               26.02356
# 4             -25.56523               26.03843
#
#    FieldMeasurement_PiezometerNumber FieldMeasurement_MeasurementDateAndTime  \
# 0                                NaN                     1990-07-03 16:26:00
# 1                                NaN                     1991-10-22 00:00:00
# ...

# %%
FieldMeasurements.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643 entries, 0 to 1642
# Data columns (total 11 columns):
# GeositeInfo_DataOwner                      1643 non-null object
# GeositeInfo_Identifier                     1643 non-null object
# GeositeInfo_GeositeType                    1643 non-null object
# GeositeInfo_Latitude                       1643 non-null float64
# GeositeInfo_Longitude                      1643 non-null float64
# FieldMeasurement_PiezometerNumber          0 non-null float64
# FieldMeasurement_MeasurementDateAndTime    195 non-null object
# FieldMeasurement_MeasurementDepth          155 non-null float64
# FieldMeasurement_ElectricalConductivity    176 non-null float64
# FieldMeasurement_pHValue                   147 non-null float64
# FieldMeasurement_Temperature               51 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 141.3+ KB

# %% [markdown]
# ## Lithology_wbw_2019912_95245_DataExport_1.csv

# %%
Lithology.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria                 039905                Borehole
# 3  Dept Water - Pretoria                 039905                Borehole
# 4  Dept Water - Pretoria                 039905                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56532               26.02356
# 2             -25.56532               26.02356
# 3             -25.56532               26.02356
# 4             -25.56532               26.02356
#
#   Lithology_DescriptorDesignation  Lithology_DescriptorName  \
# 0                             NaN                       NaN
# 1    Non-Earth Scientist: Driller                       NaN
# 2    Non-Earth Scientist: Driller                       NaN
# ...

# %%
Lithology.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4046 entries, 0 to 4045
# Data columns (total 32 columns):
# GeositeInfo_DataOwner              4046 non-null object
# GeositeInfo_Identifier             4046 non-null object
# GeositeInfo_GeositeType            4046 non-null object
# GeositeInfo_Latitude               4046 non-null float64
# GeositeInfo_Longitude              4046 non-null float64
# Lithology_DescriptorDesignation    3429 non-null object
# Lithology_DescriptorName           0 non-null float64
# Lithology_EventDate                3429 non-null object
# Lithology_DepthToTop               3429 non-null float64
# Lithology_DepthToBottom            3429 non-null float64
# Lithology_LithologyName            3429 non-null object
# Lithology_PrimaryColour            849 non-null object
# Lithology_ColourQualifier          175 non-null object
# Lithology_SecondaryColour          304 non-null object
# Lithology_CompositionQualifier     18 non-null object
# ...

# %% [markdown]
# ## OtherNumbers_wbw_2019912_94720_DataExport_1.csv

# %%
OtherNumbers.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria            2526CA00494                Borehole
# 2  Dept Water - Pretoria                 039905                Borehole
# 3  Dept Water - Pretoria                 039905                Borehole
# 4  Dept Water - Pretoria                 039905                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56581               26.03837
# 2             -25.56532               26.02356
# 3             -25.56532               26.02356
# 4             -25.56532               26.02356
#
#                        OtherNumber_OtherNumberType OtherNumber_OtherNumber
# 0  Department of Water Affairs and Forestry Number                     MP7
# 1                                      NGDB-Number             2526CA00494
# ...

# %%
OtherNumbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3052 entries, 0 to 3051
# Data columns (total 7 columns):
# GeositeInfo_DataOwner          3052 non-null object
# GeositeInfo_Identifier         3052 non-null object
# GeositeInfo_GeositeType        3052 non-null object
# GeositeInfo_Latitude           3052 non-null float64
# GeositeInfo_Longitude          3052 non-null float64
# OtherNumber_OtherNumberType    2752 non-null object
# OtherNumber_OtherNumber        2752 non-null object
# dtypes: float64(2), object(5)
# memory usage: 167.0+ KB

# %% [markdown]
# ## WaterLevels_wbw_2019912_93751_DataExport_1.csv

# %%
WaterLevels.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria                 039905                Borehole
# 3  Dept Water - Pretoria            2526CA00495                Borehole
# 4  Dept Water - Pretoria            2525DB00031                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude WaterLevel_ReferencePoint  \
# 0             -25.56581               26.03837                       NaN
# 1             -25.56532               26.02356                       NaN
# 2             -25.56532               26.02356                       NaN
# 3             -25.56523               26.03843                       NaN
# 4             -25.56503               25.99131                       NaN
#
#    WaterLevel_ReferenceHeight WaterLevel_MeasuringMethod  \
# ...

# %%
WaterLevels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3484 entries, 0 to 3483
# Data columns (total 12 columns):
# GeositeInfo_DataOwner                3484 non-null object
# GeositeInfo_Identifier               3484 non-null object
# GeositeInfo_GeositeType              3484 non-null object
# GeositeInfo_Latitude                 3484 non-null float64
# GeositeInfo_Longitude                3484 non-null float64
# WaterLevel_ReferencePoint            21 non-null object
# WaterLevel_ReferenceHeight           14 non-null float64
# WaterLevel_MeasuringMethod           1683 non-null object
# WaterLevel_WaterLevelStatus          1918 non-null object
# WaterLevel_PiezometerNumber          0 non-null float64
# WaterLevel_MeasurementDateAndTime    2728 non-null object
# WaterLevel_WaterLevel                2723 non-null float64
# dtypes: float64(5), object(7)
# memory usage: 326.8+ KB

# %% [markdown]
# ## WaterStrike_wbw_2019912_9517_DataExport_1.csv

# %%
WaterStrike.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria                 039905                Borehole
# 3  Dept Water - Pretoria            2526CA00495                Borehole
# 4  Dept Water - Pretoria            2525DB00031                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude  \
# 0             -25.56581               26.03837
# 1             -25.56532               26.02356
# 2             -25.56532               26.02356
# 3             -25.56523               26.03843
# 4             -25.56503               25.99131
#
#   WaterStrike_ConstructionCompletionDate WaterStrike_YieldMeasurementMethod  \
# 0                                    NaN                                NaN
# 1                             1991-10-29                                NaN
# ...

# %%
WaterStrike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771 entries, 0 to 1770
# Data columns (total 13 columns):
# GeositeInfo_DataOwner                     1771 non-null object
# GeositeInfo_Identifier                    1771 non-null object
# GeositeInfo_GeositeType                   1771 non-null object
# GeositeInfo_Latitude                      1771 non-null float64
# GeositeInfo_Longitude                     1771 non-null float64
# WaterStrike_ConstructionCompletionDate    1044 non-null object
# WaterStrike_YieldMeasurementMethod        176 non-null object
# WaterStrike_WaterStrikeType               1056 non-null object
# WaterStrike_SeepageValue                  567 non-null float64
# WaterStrike_DepthToTop                    1056 non-null float64
# WaterStrike_DepthToBottom                 20 non-null float64
# WaterStrike_TotalBlowYieldValue           642 non-null float64
# WaterStrike_ContributionValue             190 non-null float64
# dtypes: float64(7), object(6)
# ...

# %% [markdown]
# ## Yieldtest_wbw_2019912_95158_DataExport_1.csv

# %%
Yieldtest.head()
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
# 2  Dept Water - Pretoria            2526CA00495                Borehole
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude YieldTest_YieldTestStartDate  \
# 0             -25.56581               26.03837                          NaN
# 1             -25.56532               26.02356                          NaN
# 2             -25.56523               26.03843                          NaN
# 3             -25.56503               25.99131                          NaN
# 4             -25.56449               26.02662                          NaN
#
#   YieldTest_TestType  YieldTest_StaticWaterLevel  \
# ...

# %%
Yieldtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1702 entries, 0 to 1701
# Data columns (total 13 columns):
# GeositeInfo_DataOwner                1702 non-null object
# GeositeInfo_Identifier               1702 non-null object
# GeositeInfo_GeositeType              1702 non-null object
# GeositeInfo_Latitude                 1702 non-null float64
# GeositeInfo_Longitude                1702 non-null float64
# YieldTest_YieldTestStartDate         154 non-null object
# YieldTest_TestType                   154 non-null object
# YieldTest_StaticWaterLevel           154 non-null float64
# YieldTest_MeasurementDateTimeType    154 non-null object
# YieldTest_WaterLevel                 154 non-null float64
# YieldTest_WaterLevelStatus           154 non-null object
# YieldTest_DischargeRate              131 non-null object
# YieldTest_Quantity                   0 non-null float64
# dtypes: float64(5), object(8)
# memory usage: 173.0+ KB

# %%
test = pd.merge(Abs, Bas, on = 'GeositeInfo_Identifier', how = 'inner', copy = False)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2242 entries, 0 to 2241
# Data columns (total 45 columns):
# GeositeInfo_DataOwner_x                        2242 non-null object
# GeositeInfo_Identifier                         2242 non-null object
# GeositeInfo_GeositeType_x                      2242 non-null object
# GeositeInfo_Latitude_x                         2242 non-null float64
# GeositeInfo_Longitude_x                        2242 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
test.to_csv('test.csv', index = False)

# %%
test2 = Bas.loc[Bas['GeositeInfo_Identifier'].isin(Abs ['GeositeInfo_Identifier'])]
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
# GeositeInfo_DataOwner                    2240 non-null object
# GeositeInfo_Identifier                   2240 non-null object
# GeositeInfo_GeositeType                  2240 non-null object
# GeositeInfo_Latitude                     2240 non-null float64
# GeositeInfo_Longitude                    2240 non-null float64
# GeositeInfo_ReferenceDatum               2240 non-null object
# GeositeInfo_CoordinateMethod             2240 non-null object
# GeositeInfo_Elevation                    2240 non-null float64
# GeositeInfo_FarmName                     1939 non-null object
# GeositeInfo_FarmNumber                   1939 non-null object
# GeositeInfo_Town                         82 non-null object
# GeositeInfo_Portion                      102 non-null object
# GeositeInfo_Village                      382 non-null object
# ...

# %%
from scipy.stats import norm

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %%
norm.pdf(0, loc = 5, scale = 10)
# Out:
# 0.03520653267642995

# %%
import numpy as np

# %%
r = np.random.randn(10)

# %%
norm.pdf(r)
# Out:
# array([0.14585323, 0.13827293, 0.3496507 , 0.38518441, 0.18315915,
#        0.2140042 , 0.38016296, 0.13582284, 0.36182443, 0.04051645])

# %%
norm.logpdf(r)
# Out:
# array([-1.92515444, -1.97852581, -1.05082062, -0.95403308, -1.69739983,
#        -1.54175963, -0.96715527, -1.9964039 , -1.01659619, -3.20604712])

# %%
norm.logcdf(r)
# Out:
# array([-0.08121822, -2.62096747, -0.3620794 , -0.50340461, -0.1121146 ,
#        -2.02349068, -0.47493765, -0.07370728, -0.39938045, -0.01636141])

# %%
norm.cdf(r)
# Out:
# array([0.92199247, 0.07273246, 0.69622709, 0.60446917, 0.89394181,
#        0.13219321, 0.62192383, 0.92894357, 0.67073547, 0.98377171])

# %%
x = np.random.randn(10000)

# %%
plt.hist(x, bins = 100)
plt.show();

# %%
# Guassian dist with a standard dev of 10 and a mean of 5
p = 10*np.random.randn(10000)+5

# %%
plt.hist(p, bins = 100)
plt.show();

# %%
e = np.random.randn(10000, 2) # adding more dimensions

# %%
plt.scatter(e[:,0], e[:,1])
plt.show();

# %%
e[:, 1] = 5*e[:, 1]+2

# %%
plt.scatter(e[:, 0], e[:, 1])
plt.axis ('equal');

# %%
cov = np.array ([[1, 0.8], [0.8, 3]])

# %%
mu = np.array([0,2])

# %%
from scipy.stats import multivariate_normal as mvn
r = mvn.rvs(mean = mu, cov=cov, size = 1000)

# %%
plt.scatter(r[:, 0], r[:,1])
plt.axis('equal');

# %%
r = np.random.multivariate_normal(mean = mu, cov=cov, size = 1000)

# %%
plt.scatter(r[:, 0], r[:,1])
plt.axis('equal');

# %%
x = np.linspace(0, 100, 1000)

# %%
y = np.sin(x) + np.sin(3*x) + np.sin(5*x)

# %%
plt.plot(y);

# %%
Y = np.fft.fft(y)

# %%
plt.plot(np.abs(Y));

# %%
2*np.pi*16/100
# Out:
# 1.0053096491487339

# %%
2*np.pi*48/100
# Out:
# 3.015928947446201

# %%
2*np.pi*80/100
# Out:
# 5.026548245743669

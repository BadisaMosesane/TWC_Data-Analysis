# %%
import pandas as pd
import numpy as np
import os 
from os import listdir
import glob
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Abs = pd.read_csv ('Abstraction_wbw_2019912_93856_DataExport_1.csv')
Bas = pd.read_csv ('Basic_wbw_2019912_93716_DataExport_1.csv')
Casings = pd.read_csv ('Casings_wbw_2019912_94828_DataExport_1.csv') 
DepthDiam = pd.read_csv ('DepthDiam_wbw_2019912_94753_DataExport_1.csv')
Discharge = pd.read_csv ('Discharge_wbw_2019912_9413_DataExport_1.csv')
Equipment = pd.read_csv ('Equipment_wbw_2019912_94934_DataExport_1.csv')  
FieldMeasurements = pd.read_csv ('FieldMeasurements_wbw_2019912_9470_DataExport_1.csv')
Lithology = pd.read_csv ('Lithology_wbw_2019912_95245_DataExport_1.csv')
OtherNumbers = pd.read_csv ('OtherNumbers_wbw_2019912_94720_DataExport_1.csv')
WaterLevels = pd.read_csv ('WaterLevels_wbw_2019912_93751_DataExport_1.csv')
WaterStrike = pd.read_csv ('WaterStrike_wbw_2019912_9517_DataExport_1.csv')
Yieldtest = pd.read_csv ('Yieldtest_wbw_2019912_95158_DataExport_1.csv')

# %%
Abs ['file_name'] = "Abstraction_wbw_2019912_93856_DataExport_1.csv"
Bas ['file_name'] = "Basic_wbw_2019912_93716_DataExport_1.csv"
Casings ['file_name'] = "Casings_wbw_2019912_94828_DataExport_1.csv"
DepthDiam ['file_name'] = "DepthDiam_wbw_2019912_94753_DataExport_1.csv"
Discharge ['file_name'] = "Discharge_wbw_2019912_9413_DataExport_1.csv"
Equipment ['file_name'] = "Equipment_wbw_2019912_94934_DataExport_1.csv"
FieldMeasurements ['file_name'] = "FieldMeasurements_wbw_2019912_9470_DataExport_1.csv"
Lithology ['file_name'] = "Lithology_wbw_2019912_95245_DataExport_1.csv"
OtherNumbers ['file_name'] = "OtherNumbers_wbw_2019912_94720_DataExport_1.csv"
WaterLevels ['file_name'] = "WaterLevels_wbw_2019912_93751_DataExport_1.csv"
WaterStrike ['file_name'] = "WaterStrike_wbw_2019912_9517_DataExport_1.csv"
Yieldtest ['file_name'] = "Yieldtest_wbw_2019912_95158_DataExport_1.csv"

# %%
data = [Abs, Bas, Casings, DepthDiam, Discharge, Equipment, FieldMeasurements,
        Lithology, OtherNumbers, WaterLevels, WaterStrike, Yieldtest]

dataset = pd.concat(data, sort = False)

dataset ['dataowner'] = "Department of Water and Sanitation South Africa"
dataset ['contact_person'] = "Ramusiya, Fhedzisani"
dataset ['email'] = "RamusiyaF@dws.gov.za"

# %%
pd.set_option('display.max_columns', 129)
pd.set_option('display.max_rows', 26091)

# %%
dataset.head(2)
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
# 1  Dept Water - Pretoria                 039905                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 0             -25.56581               26.03837                   NaN
# 1             -25.56532               26.02356                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
#    Abstraction_ConversionFactorConstantValue  Abstraction_Quantity  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
#
#    Abstraction_PowerMeterReading Abstraction_WaterMeterCollectiveMeasurement  \
# ...

# %%
dataset.head().tail(2)
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 3  Dept Water - Pretoria            2525DB00031                Borehole
# 4  Dept Water - Pretoria                 039906                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 3             -25.56503               25.99131                   NaN
# 4             -25.56449               26.02662                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#    Abstraction_ConversionFactorConstantValue  Abstraction_Quantity  \
# 3                                        NaN                   NaN
# 4                                        NaN                   NaN
#
#    Abstraction_PowerMeterReading Abstraction_WaterMeterCollectiveMeasurement  \
# ...

# %%
Abs2 = dataset [dataset['file_name'] == 'Abstraction_wbw_2019912_93856_DataExport_1.csv']
Bas2 = dataset [dataset['file_name'] == 'Basic_wbw_2019912_93716_DataExport_1.csv']

# %%
Abs2.head(1)
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 0             -25.56581               26.03837                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# 0                             NaN                           NaN
#
#    Abstraction_ConversionFactorConstantValue  Abstraction_Quantity  \
# 0                                        NaN                   NaN
#
#    Abstraction_PowerMeterReading Abstraction_WaterMeterCollectiveMeasurement  \
# 0                            NaN                                         NaN
#
#    Abstraction_WaterMeterReading  Abstraction_WaterMeterMeasurementReason  \
# 0                            NaN                                      NaN
#
#   Abstraction_MeasurementMethod Abstraction_MeasurementStatus  \
# ...

# %%
Bas2.head(1)
# Out:
#    GeositeInfo_DataOwner GeositeInfo_Identifier GeositeInfo_GeositeType  \
# 0  Dept Water - Pretoria            2526CA00494                Borehole
#
#    GeositeInfo_Latitude  GeositeInfo_Longitude Abstraction_MeterType  \
# 0             -25.56581               26.03837                   NaN
#
#   Abstraction_MeasurementDateTime  Abstraction_HourMeterReading  \
# 0                             NaN                           NaN
#
#    Abstraction_ConversionFactorConstantValue  Abstraction_Quantity  \
# 0                                        NaN                   NaN
#
#    Abstraction_PowerMeterReading Abstraction_WaterMeterCollectiveMeasurement  \
# 0                            NaN                                         NaN
#
#    Abstraction_WaterMeterReading  Abstraction_WaterMeterMeasurementReason  \
# 0                            NaN                                      NaN
#
#   Abstraction_MeasurementMethod Abstraction_MeasurementStatus  \
# ...

# %%
dataset2 = pd.merge (Abs2, Bas2, on = "GeositeInfo_Identifier", how = "inner", copy = False)

# %%
dataset2.head()
# Out:
#   GeositeInfo_DataOwner_x GeositeInfo_Identifier GeositeInfo_GeositeType_x  \
# 0   Dept Water - Pretoria            2526CA00494                  Borehole
# 1   Dept Water - Pretoria                 039905                  Borehole
# 2   Dept Water - Pretoria            2526CA00495                  Borehole
# 3   Dept Water - Pretoria            2525DB00031                  Borehole
# 4   Dept Water - Pretoria                 039906                  Borehole
#
#    GeositeInfo_Latitude_x  GeositeInfo_Longitude_x Abstraction_MeterType_x  \
# 0               -25.56581                 26.03837                     NaN
# 1               -25.56532                 26.02356                     NaN
# 2               -25.56523                 26.03843                     NaN
# 3               -25.56503                 25.99131                     NaN
# 4               -25.56449                 26.02662                     NaN
#
# ...

# %%
Abs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1588 entries, 0 to 1587
# Columns: 132 entries, GeositeInfo_DataOwner to email
# dtypes: float64(55), object(77)
# memory usage: 1.6+ MB

# %%
dataset['file_name'].unique()
# Out:
# array(['Abstraction_wbw_2019912_93856_DataExport_1.csv',
#        'Basic_wbw_2019912_93716_DataExport_1.csv',
#        'Casings_wbw_2019912_94828_DataExport_1.csv',
#        'DepthDiam_wbw_2019912_94753_DataExport_1.csv',
#        'Discharge_wbw_2019912_9413_DataExport_1.csv',
#        'Equipment_wbw_2019912_94934_DataExport_1.csv',
#        'FieldMeasurements_wbw_2019912_9470_DataExport_1.csv',
#        'Lithology_wbw_2019912_95245_DataExport_1.csv',
#        'OtherNumbers_wbw_2019912_94720_DataExport_1.csv',
#        'WaterLevels_wbw_2019912_93751_DataExport_1.csv',
#        'WaterStrike_wbw_2019912_9517_DataExport_1.csv',
#        'Yieldtest_wbw_2019912_95158_DataExport_1.csv'], dtype=object)

# %%
dataset['file_name'].nunique()
# Out:
# 12

# %%
print('\n Abs: \n {}'.format(Abs.shape))
print('\n Bas: \n {}'.format(Bas.shape))
print('\n Casings: \n {}'.format(Casings.shape))
print('\n DepthDiam: \n {}'.format(DepthDiam.shape))
print('\n Discharge: \n {}'.format(Discharge.shape))
print('\n Equipment: \n {}'.format(Equipment.shape))
print('\n FieldMeasurements: \n {}'.format(FieldMeasurements.shape))
print('\n Lithology: \n {}'.format(Lithology.shape))
print('\n OtherNumbers: \n {}'.format(OtherNumbers.shape))
print('\n WaterLevels: \n {}'.format(WaterLevels.shape))
print('\n WaterStrike: \n {}'.format(WaterStrike.shape))
print('\n Yieldtest: \n {}'.format(Yieldtest.shape))
# Out:
#  Abs:
#  (1588, 16)
#
#  Bas:
#  (2240, 30)
#
#  Casings:
#  (1605, 11)
#
#  DepthDiam:
#  (1615, 9)
#
#  Discharge:
#  (1757, 9)
#
#  Equipment:
#  (1588, 20)
#
#  FieldMeasurements:
#  (1643, 11)
#
#  Lithology:
#  (4046, 32)
#
#  OtherNumbers:
#  (3052, 7)
#
#  WaterLevels:
#  (3484, 12)
#
#  WaterStrike:
#  (1771, 13)
#
#  Yieldtest:
#  (1702, 13)

# %%
print('Total row count: ', 1588+2240+1605+1615+1757+1588+1643+4046+3052+3484+1771+1702)
# Out:
# Total row count:  26091

# %%
print('Total col count: ', 16+30+11+9+9+20+11+32+7+12+13+13)
# Out:
# Total col count:  183

# %%
print(Abs ['GeositeInfo_Identifier'].nunique())
print(Bas ['GeositeInfo_Identifier'].nunique())
print(Casings ['GeositeInfo_Identifier'].nunique())
print(DepthDiam ['GeositeInfo_Identifier'].nunique())
print(Discharge ['GeositeInfo_Identifier'].nunique())
print(Equipment ['GeositeInfo_Identifier'].nunique())
print(FieldMeasurements ['GeositeInfo_Identifier'].nunique())
print(Lithology ['GeositeInfo_Identifier'].nunique())
print(OtherNumbers ['GeositeInfo_Identifier'].nunique())
print(WaterLevels ['GeositeInfo_Identifier'].nunique())
print(WaterStrike ['GeositeInfo_Identifier'].nunique())
print(Yieldtest ['GeositeInfo_Identifier'].nunique())
# Out:
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587
# 1587

# %%
Abs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1588 entries, 0 to 1587
# Data columns (total 16 columns):
# GeositeInfo_DataOwner                          1588 non-null object
# GeositeInfo_Identifier                         1588 non-null object
# GeositeInfo_GeositeType                        1588 non-null object
# GeositeInfo_Latitude                           1588 non-null float64
# GeositeInfo_Longitude                          1588 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
Bas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
# GeositeInfo_DataOwner                    2240 non-null object
# GeositeInfo_Identifier                   2240 non-null object
# GeositeInfo_GeositeType                  2240 non-null object
# GeositeInfo_Latitude                     2240 non-null float64
# GeositeInfo_Longitude                    2240 non-null float64
# GeositeInfo_ReferenceDatum               2240 non-null object
# GeositeInfo_CoordinateMethod             2240 non-null object
# GeositeInfo_Elevation                    2240 non-null float64
# GeositeInfo_FarmName                     1939 non-null object
# GeositeInfo_FarmNumber                   1939 non-null object
# GeositeInfo_Town                         82 non-null object
# GeositeInfo_Portion                      102 non-null object
# GeositeInfo_Village                      382 non-null object
# ...

# %%
Abs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1588 entries, 0 to 1587
# Data columns (total 20 columns):
# GeositeInfo_DataOwner                          1588 non-null object
# GeositeInfo_Identifier                         1588 non-null object
# GeositeInfo_GeositeType                        1588 non-null object
# GeositeInfo_Latitude                           1588 non-null float64
# GeositeInfo_Longitude                          1588 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
Bas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 34 columns):
# GeositeInfo_DataOwner                    2240 non-null object
# GeositeInfo_Identifier                   2240 non-null object
# GeositeInfo_GeositeType                  2240 non-null object
# GeositeInfo_Latitude                     2240 non-null float64
# GeositeInfo_Longitude                    2240 non-null float64
# GeositeInfo_ReferenceDatum               2240 non-null object
# GeositeInfo_CoordinateMethod             2240 non-null object
# GeositeInfo_Elevation                    2240 non-null float64
# GeositeInfo_FarmName                     1939 non-null object
# GeositeInfo_FarmNumber                   1939 non-null object
# GeositeInfo_Town                         82 non-null object
# GeositeInfo_Portion                      102 non-null object
# GeositeInfo_Village                      382 non-null object
# ...

# %%
new_data = [Abs, Bas]

rims_new = pd.concat(new_data, sort=False)

# %%
rims_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3828 entries, 0 to 2239
# Data columns (total 45 columns):
# GeositeInfo_DataOwner                          3828 non-null object
# GeositeInfo_Identifier                         3828 non-null object
# GeositeInfo_GeositeType                        3828 non-null object
# GeositeInfo_Latitude                           3828 non-null float64
# GeositeInfo_Longitude                          3828 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
rims_new ['file_name'].unique()
# Out:
# array(['Abstraction_wbw_2019912_93856_DataExport_1.csv',
#        'Basic_wbw_2019912_93716_DataExport_1.csv'], dtype=object)

# %%
rims_new.to_csv('rims_new.csv', index = False)

# %%
dataset = pd.merge (Abs, Bas, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude'}, inplace = True)


dataset.shape
# Out:
# (2242, 49)

# %%
dataset ["dataowner"] = dataset ["dataowner_x"] + dataset ["dataowner_y"]
dataset ["contact_person"] = dataset ["contact_person_x"] + dataset ["contact_person_y"]
dataset ["email"] = dataset ["email_x"] + dataset ["email_y"]
dataset ["file_name"] = dataset ["file_name_x"] + dataset ["file_name_y"]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2242 entries, 0 to 2241
# Data columns (total 53 columns):
# GeositeInfo_DataOwner                          2242 non-null object
# GeositeInfo_Identifier                         2242 non-null object
# GeositeInfo_GeositeType                        2242 non-null object
# GeositeInfo_Latitude                           2242 non-null float64
# GeositeInfo_Longitude                          2242 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
dataset ['file_name'].unique()
# Out:
# array(['Abstraction_wbw_2019912_93856_DataExport_1.csvBasic_wbw_2019912_93716_DataExport_1.csv'],
#       dtype=object)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2242 entries, 0 to 2241
# Data columns (total 49 columns):
# GeositeInfo_DataOwner                          2242 non-null object
# GeositeInfo_Identifier                         2242 non-null object
# GeositeInfo_GeositeType                        2242 non-null object
# GeositeInfo_Latitude                           2242 non-null float64
# GeositeInfo_Longitude                          2242 non-null float64
# Abstraction_MeterType                          1 non-null object
# Abstraction_MeasurementDateTime                1 non-null object
# Abstraction_HourMeterReading                   0 non-null float64
# Abstraction_ConversionFactorConstantValue      0 non-null float64
# Abstraction_Quantity                           1 non-null float64
# Abstraction_PowerMeterReading                  0 non-null float64
# Abstraction_WaterMeterCollectiveMeasurement    1 non-null object
# ...

# %%
Casings ['dataowner'] = "Department of Water and Sanitation South Africa"
Casings ['contact_person'] = "Ramusiya, Fhedzisani"
Casings ['email'] = "RamusiyaF@dws.gov.za"
Casings ['file_name'] = "Casings_wbw_2019912_94828_DataExport_1.csv"
DepthDiam ['dataowner'] = "Department of Water and Sanitation South Africa"
DepthDiam ['contact_person'] = "Ramusiya, Fhedzisani"
DepthDiam ['email'] = "RamusiyaF@dws.gov.za"
DepthDiam ['file_name'] = "DepthDiam_wbw_2019912_94753_DataExport_1.csv"
Discharge ['dataowner'] = "Department of Water and Sanitation South Africa"
Discharge ['contact_person'] = "Ramusiya, Fhedzisani"
Discharge ['email'] = "RamusiyaF@dws.gov.za"
Discharge ['file_name'] = "Discharge_wbw_2019912_9413_DataExport_1.csv"
Equipment ['dataowner'] = "Department of Water and Sanitation South Africa"
Equipment ['contact_person'] = "Ramusiya, Fhedzisani"
Equipment ['email'] = "RamusiyaF@dws.gov.za"
Equipment ['file_name'] = "Equipment_wbw_2019912_94934_DataExport_1.csv"
FieldMeasurements ['dataowner'] = "Department of Water and Sanitation South Africa"
FieldMeasurements ['contact_person'] = "Ramusiya, Fhedzisani"
FieldMeasurements ['email'] = "RamusiyaF@dws.gov.za"
FieldMeasurements ['file_name'] = "FieldMeasurements_wbw_2019912_9470_DataExport_1.csv"
Lithology ['dataowner'] = "Department of Water and Sanitation South Africa"
Lithology ['contact_person'] = "Ramusiya, Fhedzisani"
Lithology ['email'] = "RamusiyaF@dws.gov.za"
Lithology ['file_name'] = "Lithology_wbw_2019912_95245_DataExport_1.csv"
OtherNumbers ['dataowner'] = "Department of Water and Sanitation South Africa"
OtherNumbers ['contact_person'] = "Ramusiya, Fhedzisani"
OtherNumbers ['email'] = "RamusiyaF@dws.gov.za"
OtherNumbers ['file_name'] = "OtherNumbers_wbw_2019912_94720_DataExport_1.csv"
WaterLevels ['dataowner'] = "Department of Water and Sanitation South Africa"
WaterLevels ['contact_person'] = "Ramusiya, Fhedzisani"
WaterLevels ['email'] = "RamusiyaF@dws.gov.za"
WaterLevels ['file_name'] = "WaterLevels_wbw_2019912_93751_DataExport_1.csv"
WaterStrike ['dataowner'] = "Department of Water and Sanitation South Africa"
WaterStrike ['contact_person'] = "Ramusiya, Fhedzisani"
WaterStrike ['email'] = "RamusiyaF@dws.gov.za"
WaterStrike ['file_name'] = "WaterStrike_wbw_2019912_9517_DataExport_1.csv"
Yieldtest ['dataowner'] = "Department of Water and Sanitation South Africa"
Yieldtest ['contact_person'] = "Ramusiya, Fhedzisani"
Yieldtest ['email'] = "RamusiyaF@dws.gov.za"
Yieldtest ['file_name'] = "Yieldtest_wbw_2019912_95158_DataExport_1.csv"

# %%
dataset = pd.merge (Abs, Bas, on = ["GeositeInfo_Identifier", "dataowner", "contact_person", "email", "file_name"], how = "inner", copy = False)
#dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y'], axis = 1, inplace = True)
#dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         #'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude'}, inplace = True)
dataset.shape
# Out:
# (0, 49)

# %%
dataset = pd.merge (dataset, Casings, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)

dataset ['dataowner'] = "Department of Water and Sanitation South Africa"
dataset ['contact_person'] = "Ramusiya, Fhedzisani"
dataset ['email'] = "RamusiyaF@dws.gov.za"
dataset ['file_name'] = "Basic_wbw_2019912_93716_DataExport_1.csv"

dataset.shape
# Out:
# (2263, 51)

# %%
dataset = pd.merge (dataset, DepthDiam, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (2299, 55)

# %%
dataset = pd.merge (dataset, Discharge, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (2558, 59)

# %%
dataset = pd.merge (dataset, Equipment, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)

# %%
dataset = pd.merge (dataset, FieldMeasurements, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (2747, 80)

# %%
dataset = pd.merge (dataset, Lithology, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (6647, 107)

# %%
dataset = pd.merge (dataset, OtherNumbers, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (18291, 109)

# %%
dataset = pd.merge (dataset, WaterLevels, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (673715, 116)

# %%
dataset = pd.merge (dataset, WaterStrike, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (694524, 124)

# %%
dataset = pd.merge (dataset, Yieldtest, on = "GeositeInfo_Identifier", how = "inner", copy = False)
dataset.drop(['GeositeInfo_DataOwner_y', 'GeositeInfo_GeositeType_y', 'GeositeInfo_Latitude_y', 'GeositeInfo_Longitude_y',
             'dataowner_y', 'contact_person_y', 'email_y', 'file_name_y'], axis = 1, inplace = True)
dataset.rename(columns = {'GeositeInfo_DataOwner_x': 'GeositeInfo_DataOwner', 'GeositeInfo_GeositeType_x': 'GeositeInfo_GeositeType', 
                         'GeositeInfo_Latitude_x': 'GeositeInfo_Latitude', 'GeositeInfo_Longitude_x': 'GeositeInfo_Longitude',
                         'dataowner_x': 'dataowner', 'contact_person_x': 'contact_person', 'email_x': 'email', 'file_name_x': 'file_name'}, inplace = True)
dataset.shape
# Out:
# (755276, 132)

# %%
dataset ['file_name'].unique()
# Out:
# array(['Basic_wbw_2019912_93716_DataExport_1.csv'], dtype=object)

# %%
df = [Abs, Bas, Casings, DepthDiam, Discharge, Equipment, FieldMeasurements,
      Lithology, OtherNumbers, WaterLevels, WaterStrike, Yieldtest] 

from functools import reduce

df_merged = reduce(lambda  left,right: pd.merge(left,right, on = 'GeositeInfo_Identifier', how = 'inner'), df)

# %%
dataset.drop_duplicates(subset = 'GeositeInfo_Identifier', keep = "first", inplace = True)
